# %%
#!/usr/bin/env bash
# build the docs
cd docs
make clean
make html
cd ..
# Out:
# bash: !/usr/bin/env: event not found
# Removing everything under 'build'...
# Running Sphinx v1.6.5
# making output directory...
# loading pickled environment... not yet created
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 2 source files that are out of date
# updating environment: 2 added, 0 changed, 0 removed
# reading sources... [ 50%] includeme
# Generating grammar tables from /usr/lib/python3.5/lib2to3/Grammar.txt
# Generating grammar tables from /usr/lib/python3.5/lib2to3/PatternGrammar.txt
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Parameters:
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# reading sources... [100%] index
#
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_entr_v_ut:15: WARNING: Definition list ends without a blank line; unexpected unindent.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_entr_v_ut:24: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_mach_number:12: WARNING: Inline emphasis start-string without end-string.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_mach_number:14: WARNING: Inline emphasis start-string without end-string.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.prof_compare:39: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.set_YProf_path:11: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile:43: WARNING: Unknown directive type "autosummary".
#
# .. autosummary::
#    :toctree:
#
#    Aprof_time
#    Dinv
#    Dov
#    Dov2
#    Dsolve
#    Dsolvedown
#    Dsolvedownexp
#    Richardson_plot
#    abu_chart
#    abu_chartMulti
#    abu_flux_chart
#    abu_profile
#    boundary_radius
#    computeData
#    density_profile
#    elem_abund
#    elemental_abund
#    entrainment_rate
#    findFile
#    get
#    getCattrs
#    getColData
#    getCycleData
#    getDCols
#    getHattrs
#    getHeaderData
#    get_mass_fraction
#    iso_abund
#    iso_abundMulti
#    movie
#    ndumpDict
#    plot
#    plotMulti
#    plot_entrainment_rates
#    plot_isopattern
#    plot_isoratios
#    plot_prof_1
#    plotprofMulti
#    prof_time
#    readTop
#    spacetime_diagram
#    tEkmax
#    tvmax
#    vaverage
#    vprof_time
#    vprofs
#    ye_profile
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.Richardson_plot:26: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.Dsolvedownexp:16: WARNING: Definition list ends without a blank line; unexpected unindent.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.plot_entrainment_rates:6: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.get:24: WARNING: Block quote ends without a blank line; unexpected unindent.
# looking for now-outdated files... none found
# pickling environment... done
# checking consistency... done
# preparing documents... done
# writing output... [ 50%] includeme
# writing output... [100%] index
#
# generating indices... genindex py-modindex
# writing additional pages... search
# copying images... [100%] ../build/plot_directive/includeme-1.png
#
# copying static files... WARNING: html_static_path entry '/home/user/PyPPM/docs/source/_static' does not exist
# done
# copying extra files... done
# dumping search index in English (code: en) ... done
# dumping object inventory... done
# build succeeded, 12 warnings.
#
# Build finished. The HTML pages are in build/html.

# %%
# commit and push
git add -A
git commit -m "building and pushing docs"
git push origin master
# Out:
# [master a9cc2d7] building and pushing docs
#  17 files changed, 38 insertions(+), 7 deletions(-)
#  rewrite docs/build/doctrees/environment.pickle (98%)
#  rewrite docs/build/doctrees/includeme.doctree (87%)
#  rewrite docs/build/doctrees/index.doctree (96%)
#  create mode 100644 docs/build/html/_images/includeme-1.png
#  create mode 100644 docs/build/html/includeme-1.hires.png
#  create mode 100644 docs/build/html/includeme-1.pdf
#  create mode 100644 docs/build/html/includeme-1.png
#  create mode 100644 docs/build/html/includeme-1.py
#  rewrite docs/build/html/searchindex.js (69%)
#  create mode 100644 docs/build/plot_directive/includeme-1.hires.png
#  create mode 100644 docs/build/plot_directive/includeme-1.pdf
#  create mode 100644 docs/build/plot_directive/includeme-1.png
# Username for 'https://github.com':

# %%
# switch branches and pull the data we want
git checkout gh-pages
rm -rf _sources _static
touch .nojekyll

# %%
git checkout master docs/build/html
mv ./docs/build/html/* ./
rm -rf ./docs
git add -A
git commit -m "publishing updated docs..."

# %%
git push origin gh-pages

# %%
# switch back
git checkout master
