# %%
#!/usr/bin/env bash
# build the docs
cd docs
make clean
make html
cd ..
# Out:
# Removing everything under 'build'...
# Running Sphinx v1.6.5
# making output directory...
# loading pickled environment... not yet created
# building [mo]: targets for 0 po files that are out of date
# building [html]: targets for 2 source files that are out of date
# updating environment: 2 added, 0 changed, 0 removed
# reading sources... [ 50%] includeme
# Generating grammar tables from /usr/lib/python3.5/lib2to3/Grammar.txt
# Generating grammar tables from /usr/lib/python3.5/lib2to3/PatternGrammar.txt
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Parameters:
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Output
#   warn("Unknown section %s" % key)
# /usr/local/lib/python3.5/dist-packages/numpydoc/docscrape.py:139: UserWarning: Unknown section Example
#   warn("Unknown section %s" % key)
# reading sources... [100%] index
#
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_diffusion_profiles:32: WARNING: Definition list ends without a blank line; unexpected unindent.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_entr_v_ut:24: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_luminosity:6: WARNING: Inline emphasis start-string without end-string.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.plot_luminosity:8: WARNING: Inline emphasis start-string without end-string.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.prof_compare:39: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.set_YProf_path:11: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile:10: WARNING: Unknown directive type "autosummary".
#
# .. autosummary::
#    :toctree:
#
#    Aprof_time
#    Dinv
#    Dov
#    Dov2
#    Dsolve
#    Dsolvedown
#    Dsolvedownexp
#    Richardson_plot
#    abu_chart
#    abu_chartMulti
#    abu_flux_chart
#    abu_profile
#    boundary_radius
#    computeData
#    density_profile
#    elem_abund
#    elemental_abund
#    entrainment_rate
#    findFile
#    get
#    getCattrs
#    getColData
#    getCycleData
#    getDCols
#    getHattrs
#    getHeaderData
#    get_mass_fraction
#    iso_abund
#    iso_abundMulti
#    movie
#    ndumpDict
#    plot
#    plotMulti
#    plot_entrainment_rates
#    plot_isopattern
#    plot_isoratios
#    plot_prof_1
#    plotprofMulti
#    prof_time
#    readTop
#    spacetime_diagram
#    tEkmax
#    tvmax
#    vaverage
#    vprof_time
#    vprofs
#    ye_profile
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.Richardson_plot:26: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.Dsolvedown:58: WARNING: Definition list ends without a blank line; unexpected unindent.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.plot_entrainment_rates:6: WARNING: Unexpected indentation.
# /home/user/PyPPM/docs/ppmpy/ppm.py:docstring of ppmpy.ppm.yprofile.findFile:22: WARNING: Block quote ends without a blank line; unexpected unindent.
# looking for now-outdated files... none found
# pickling environment... done
# checking consistency... done
# preparing documents... done
# writing output... [ 50%] includeme
# writing output... [100%] index
#
# generating indices... genindex py-modindex
# writing additional pages... search
# copying static files... done
# copying extra files... done
# dumping search index in English (code: en) ... done
# dumping object inventory... done
# build succeeded, 11 warnings.
#
# Build finished. The HTML pages are in build/html.

# %%
# commit and push
git add -A
git commit -m "building and pushing docs"
git push origin master
# Out:
# [master 921ee0e] building and pushing docs
#  71 files changed, 2459 insertions(+), 15781 deletions(-)
#  delete mode 100644 .ipynb_checkpoints/Untitled1-checkpoint.ipynb
#  delete mode 100644 Examples_NewPPMpy.ipynb
#  delete mode 100644 README.rst
#  rename Untitled1.ipynb => Untitled.ipynb (100%)
#  delete mode 100644 docs/_build/html/.doctrees/README.doctree
#  delete mode 100644 docs/_build/html/.doctrees/environment.pickle
#  delete mode 100644 docs/_build/html/.doctrees/index.doctree
#  delete mode 100644 docs/_build/html/.doctrees/ppmpy/PPM.doctree
#  delete mode 100644 docs/_build/html/.doctrees/ppmpy/index.doctree
#  delete mode 100644 docs/_build/html/_sources/README.rst.txt
#  delete mode 100644 docs/_build/html/_sources/ppmpy/PPM.rst.txt
#  delete mode 100644 docs/_build/html/_sources/ppmpy/index.rst.txt
#  delete mode 100644 docs/_build/html/genindex.html
#  delete mode 100644 docs/_build/html/objects.inv
#  delete mode 100644 docs/_build/html/ppmpy/PPM.html
#  delete mode 100644 docs/_build/html/ppmpy/index.html
#  delete mode 100644 docs/_build/html/searchindex.js
#  create mode 100644 docs/build/doctrees/environment.pickle
#  create mode 100644 docs/build/doctrees/includeme.doctree
#  create mode 100644 docs/build/doctrees/index.doctree
#  rename docs/{_build => build}/html/.buildinfo (82%)
#  create mode 100644 docs/build/html/.nojekyll
#  create mode 100644 docs/build/html/_sources/includeme.rst.txt
#  create mode 100644 docs/build/html/_sources/index.rst.txt
#  rename docs/{_build => build}/html/_static/ajax-loader.gif (100%)
#  rename docs/{_build => build}/html/_static/alabaster.css (100%)
#  rename docs/{_build => build}/html/_static/basic.css (100%)
#  rename docs/{_build => build}/html/_static/comment-bright.png (100%)
#  rename docs/{_build => build}/html/_static/comment-close.png (100%)
#  rename docs/{_build => build}/html/_static/comment.png (100%)
#  rename docs/{_build => build}/html/_static/custom.css (100%)
#  rename docs/{_build => build}/html/_static/doctools.js (100%)
#  rename docs/{_build => build}/html/_static/down-pressed.png (100%)
#  rename docs/{_build => build}/html/_static/down.png (100%)
#  rename docs/{_build => build}/html/_static/file.png (100%)
#  rename docs/{_build => build}/html/_static/jquery-3.1.0.js (100%)
#  rename docs/{_build => build}/html/_static/jquery.js (100%)
#  rename docs/{_build => build}/html/_static/minus.png (100%)
#  rename docs/{_build => build}/html/_static/plus.png (100%)
#  rename docs/{_build => build}/html/_static/pygments.css (100%)
#  rename docs/{_build => build}/html/_static/searchtools.js (100%)
#  rename docs/{_build => build}/html/_static/underscore-1.3.1.js (100%)
#  rename docs/{_build => build}/html/_static/underscore.js (100%)
#  rename docs/{_build => build}/html/_static/up-pressed.png (100%)
#  rename docs/{_build => build}/html/_static/up.png (100%)
#  rename docs/{_build => build}/html/_static/websupport.js (100%)
#  create mode 100644 docs/build/html/genindex.html
#  create mode 100644 docs/build/html/includeme.html
#  rename docs/{_build => build}/html/index.html (81%)
#  create mode 100644 docs/build/html/objects.inv
#  rename docs/{_build/html/README.html => build/html/py-modindex.html} (75%)
#  rename docs/{_build => build}/html/search.html (97%)
#  create mode 100644 docs/build/html/searchindex.js
#  delete mode 100644 docs/conf.py
#  rename ppmpy/PPM.rst => docs/ppmpy/PPMpy.rst (100%)
#  rename {ppmpy => docs/ppmpy}/__init__.py (100%)
#  create mode 100644 docs/ppmpy/__init__.pyc
#  create mode 100644 docs/ppmpy/__pycache__/__init__.cpython-35.pyc
#  rename {ppmpy => docs/ppmpy}/__pycache__/ppm.cpython-35.pyc (99%)
#  rename docs/{_build/html/_sources/index.rst.txt => ppmpy/index.rst} (90%)
#  rename {ppmpy => docs/ppmpy}/ppm.py (99%)
#  create mode 100644 docs/source/conf.py
#  create mode 100644 docs/source/includeme.rst
#  rename docs/{ => source}/index.rst (84%)
#  delete mode 100644 ppm_rprof.py
#  delete mode 100644 ppmpy demo.ipynb
#  delete mode 100644 ppmpy/__pycache__/__init__.cpython-35.pyc
#  delete mode 100644 ppmpy/index.rst
#  delete mode 100644 ppmtest.py
#  delete mode 100644 requirements.txt
# Username for 'https://github.com':

# %%
# Out:
# bash: jerichooconnell: command not found
# bash: J3richo31415: command not found
# : 127

# %%
# switch branches and pull the data we want
git checkout gh-pages
rm -rf .
touch .nojekyll
git checkout master docs/build/html
mv ./docs/build/html/* ./
rm -rf ./docs
git add -A
git commit -m "publishing updated docs..."
git push origin gh-pages

# %%
# switch back
git checkout master
